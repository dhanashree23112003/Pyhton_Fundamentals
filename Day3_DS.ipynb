# %% [markdown]
# **SETS**
#
# 1.Python data Structure
#
# 2.{}
#
# 3.Unordered(order of element is not defined)
#
# 4.Unchangable -> INBUILT
#
# 5.It does not support duplicacy

# %%
seti = {11, 3, 7, 1, 8}

# %%
type(seti)
# Out:
# set

# %%
seti
# Out:
# {1, 3, 7, 8, 11}

# %%
seti
# Out:
# {1, 3, 7, 8, 11}

# %%
setii = {1,2,3,4,5,1,2,3,2,3,4}

# %%
setii
# Out:
# {1, 2, 3, 4, 5}

# %%
#Access the elements in a set
seti = {"apples", "mangoes", "cherries"}

# %%
seti
# Out:
# {'apples', 'cherries', 'mangoes'}

# %%
seti[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-dbb4114f81fd> in <cell line: 1>()
# ----> 1 seti[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# To access the elementin a set.
#
# Convert the set to list

# %%
listi = list(seti)

# %%
listi[0]
# Out:
# 'cherries'

# %%
listi
# Out:
# ['cherries', 'mangoes', 'apples']

# %%
listi[0] ="Bananas"

# %%
listi
# Out:
# ['Bananas', 'mangoes', 'apples']

# %%
seti = set(listi)

# %%
"Bananas" in seti
# Out:
# True

# %%
#CRUD Operation

# %%
set_a = {"apples", "bananas", "cherries"}

set_b = {"pineapple", "mangoes", "papaya"}

# %%
#Adding the two sets

set_a.update(set_b)

# %%
set_a
# Out:
# {'apples', 'bananas', 'cherries', 'mangoes', 'papaya', 'pineapple'}

# %%
set_a.add("grapes")

#set_c = {"grapes", "kiwi"}

# %%
set_a
# Out:
# {'apples', 'bananas', 'cherries', 'grapes', 'mangoes', 'papaya', 'pineapple'}

# %%
set_a.add("kiwi")

# %%
set_a
# Out:
# {'apples',
#  'bananas',
#  'cherries',
#  'grapes',
#  'kiwi',
#  'mangoes',
#  'papaya',
#  'pineapple'}

# %% [markdown]
# Delete (Crud)

# %%
#set_a.remove("kiwi")

# %%
set_a
# Out:
# {'apples', 'bananas', 'cherries', 'grapes', 'mangoes', 'papaya', 'pineapple'}

# %%
set_a.discard("kiwi")

# %%
set_a
# Out:
# {'apples', 'bananas', 'cherries', 'grapes', 'mangoes', 'papaya', 'pineapple'}

# %%
#clear()

# %%
set_a.clear()

# %%
set_a
# Out:
# set()

# %%
set_a = {"apple", "bananas", "cherries"}
set_e = {"apples"}
set_b = {"google", "microsoft", "Apples"}

# %%
set_c = set_a.union(set_b)

# %%
set_c
# Out:
# {'Apples', 'apple', 'bananas', 'cherries', 'google', 'microsoft'}

# %%
set_c = set_a.intersection(set_b)

# %%
set_c
# Out:
# set()

# %%
set_c = set_a.difference(set_b)

# %%
set_c
# Out:
# {'apple', 'bananas', 'cherries'}

# %% [markdown]
# Tuple
#
# 1.Data Structure
#
# 2.Immutable
#
# 3.()
#
# 4.It allows the duplicacy

# %%
tupl = ("Apples", "Mangoes", "Cherries")

# %%
lis = list(tupl)

# %%
type(tupl)
# Out:
# tuple

# %%
#Access the elements in a Tuple
tupl[1]
# Out:
# 'Mangoes'

# %%
#tupl[1] #postive indexing
#tupl[-1] #negative indexing
tupl[1:3]
# Out:
# ('Mangoes', 'Cherries')

# %%
tupl[0:3]
# Out:
# ('Apples', 'Mangoes', 'Cherries')

# %%
tupl = tuple(lis)

# %%
lis
# Out:
# ['Apples', 'Mangoes', 'Cherries']

# %% [markdown]
# Tuple -> list -> perform the operation -> tuple

# %%
tupl
# Out:
# ('Apples', 'Mangoes', 'Cherries')

# %%
tuples =("pear",)

# %%
#Adding the tuple in tuples

tupl = tupl + tuples

# %%
tupl
# Out:
# ('Apples', 'Mangoes', 'Cherries', 'pear')

# %%
tupl += tuples

# %%
count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-455223e74664> in <cell line: 1>()
# ----> 1 count()
#
# NameError: name 'count' is not defined

# %%
tu = (1,2,3,4,1,2,2,2,2,3)

# %%
tu.count(2)
# Out:
# 5

# %%
#find index
tu.index(4)
# Out:
# 3

# %%
tu.index(1) # index of first occurence
# Out:
# 0

# %% [markdown]
# **Dictionary**
#
# 1.Python Data Structure
#
# 2.{}
#
# 3.key:value pair
#
# 4.Homogoneous means
#
# 5.ordered
#
# 6.mutable -> changable

# %%
di = {"table":"A wooden plank or a sheet", "table": "it is a toy"}

# %%
type(di)
# Out:
# dict

# %%
di
# Out:
# {'table': 'it is a toy'}

# %%
# it will take the last value because of last occurence is taken

# %%
# cannot have duplicate value

# %%
dic = {"book":"Knowledge", "laptop": "elec", "pen":"an instrument"}

# %%
#CRUD

# %%
asd = {"key":"value"}

# %%
#update the dictionary:

# %%
dic["book"] #->List
# Out:
# 'Knowledge'

# %%
dic.get("book") #-> Dictionary
# Out:
# 'Knowledge'

# %%
dic["book"] = "Hello world" #->function of list

# %%
dic
# Out:
# {'book': 'Hello world', 'laptop': 'elec', 'pen': 'an instrument'}

# %%
#update()

dic.update({"book":"meow meow"}) #-> Dict concept

# %%
dic
# Out:
# {'book': 'meow meow', 'laptop': 'elec', 'pen': 'an instrument'}

# %%
# Remove adictionary

# %%
dic
# Out:
# {'book': 'meow meow', 'laptop': 'elec', 'pen': 'an instrument'}

# %%
#dic.pop("book")

# %%
dic
# Out:
# {'book': 'meow meow', 'laptop': 'elec', 'pen': 'an instrument'}

# %%
#popitem -> It will delete/remove the last item (by default)

# %%
#dic.popitem()

# %%
dic
# Out:
# {'book': 'meow meow', 'laptop': 'elec', 'pen': 'an instrument'}

# %%
#dic.clear()

# %%
dic
# Out:
# {'book': 'meow meow', 'laptop': 'elec', 'pen': 'an instrument'}

# %%
dic.keys()
# Out:
# dict_keys(['book', 'laptop', 'pen'])

# %%
dic.values()
# Out:
# dict_values(['meow meow', 'elec', 'an instrument'])

# %%
dic
# Out:
# {'book': 'meow meow', 'laptop': 'elec', 'pen': 'an instrument'}

# %%
meow = {"cloud":["aws", 'gcp', 'azure', "heroku"]}

# %%
dics= {"python":{"data": 12, "Yept":34}} # values is inside the datatype so it doesnt matter what values it is

# %%
dics
# Out:
# {'python': {'data': 12, 'Yept': 34}}

# %%
dics["python"]
# Out:
# {'data': 12, 'Yept': 34}

# %%
dics["python"]["data"]
# Out:
# 12

# %%
dics.get("python")
# Out:
# {'data': 12, 'Yept': 34}

# %%
dics.get("python").get("data")
# Out:
# 12
